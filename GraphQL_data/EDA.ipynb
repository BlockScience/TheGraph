# %% [markdown]
# # Find a delagator with an undelegate action

# %%
import pandas as pd

# %%
delegate_df = pd.read_csv('merged.csv', low_memory = False)
delegate_df.head()
# Out:
#              type  blockNumber                                   delegator  \
# 0  stakeDelegates     11474307  0x9fe0a203e190d87cef6b4b80b24fae73f243b3ea
# 1  stakeDelegates     11474332  0xd776a7306ee6a060cebb46b46d305e88fd39ba84
# 2  stakeDelegates     11474425  0x68476977382d9cb85d11775b79252ee7d2859738
# 3  stakeDelegates     11474479  0x219688c6156edea2e2ca7e2036c1c5b7f6451169
# 4  stakeDelegates     11474488  0x9700086478e637a60f5668b70a8c829bdbc3cef7
#
#                                                   id  \
# 0  0x938641c2dbfd4562c7ab8c60ca98f11394d161ead6b9...
# 1  0x67278b0af539dff48945b3a430ada90de00526aed433...
# 2  0x45ee9b1a9a7cc55abe79ee1b83f416e68bd4595aa60e...
# 3  0xcaf570618eba9a32af37f88b1d95219e24c403509f2f...
# 4  0x5d2c06ff4961c9cff1269f2d64aa7b0522ab9d4ac9ee...
#
#                                       indexer  logIndex  \
# 0  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e        17
# 1  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e        38
# 2  0xf3f182e859f789af8d6c2223d15c691471c79a2b        51
# 3  0x8e297141f9dc76f4d71741da1a1e47294cf0fde2        16
# 4  0x4167eb613d784c910f5dc0f3f0515d61ec6ec8df       175
#
#                      shares                    tokens  eventTime  until  ...  \
# 0  165851137200000000000000  165851137200000000000000        NaN    NaN  ...
# 1  251819644650000000000000  251819644650000000000000        NaN    NaN  ...
# 2  102856115100000000000000  102856115100000000000000        NaN    NaN  ...
# 3  101129325058601450000000  101129325058601450000000        NaN    NaN  ...
# 4      99500000000000000000      99500000000000000000        NaN    NaN  ...
#
#   epoch  subgraphDeploymentID curationFees from rebateFees isDelegator sender  \
# 0   NaN                   NaN          NaN  NaN        NaN         NaN    NaN
# 1   NaN                   NaN          NaN  NaN        NaN         NaN    NaN
# 2   NaN                   NaN          NaN  NaN        NaN         NaN    NaN
# 3   NaN                   NaN          NaN  NaN        NaN         NaN    NaN
# 4   NaN                   NaN          NaN  NaN        NaN         NaN    NaN
#
#   indexingRewardCut  queryFeeCut  delegationFees
# 0               NaN          NaN             NaN
# 1               NaN          NaN             NaN
# 2               NaN          NaN             NaN
# 3               NaN          NaN             NaN
# 4               NaN          NaN             NaN
#
# [5 rows x 21 columns]

# %%
len(delegate_df)
# Out:
# 67560

# %%
delegate_df.dtypes
# Out:
# type                     object
# blockNumber               int64
# delegator                object
# id                       object
# indexer                  object
# logIndex                  int64
# shares                   object
# tokens                   object
# eventTime               float64
# until                   float64
# allocationID             object
# epoch                   float64
# subgraphDeploymentID     object
# curationFees             object
# from                     object
# rebateFees               object
# isDelegator              object
# sender                   object
# indexingRewardCut       float64
# queryFeeCut             float64
# delegationFees           object
# dtype: object

# %%
delegate_df.drop_duplicates(inplace = True)

# %%
#delegate_df.dropna(subset = ['delegator'], inplace = True)

# %%
delegate_df['delegator'].value_counts().head(20)
# Out:
# 0x63f8168f665f79101a0e0da2313cd1391e1c5e27    204
# 0x40f657e85bbb5cc7beb402da315c3fe1974442bf    122
# 0xdead40de4b54d32da6965e80b4161b321ca99d56     84
# 0xad6ee7c40d7d80a6c404e82e77cde5c5088e98a5     78
# 0x70b91ef86b5199c8016a4e123fae5712e4f8cc55     63
# 0x58514ada5f7926c99bfcfa4f2f91294598f084f5     55
# 0x1819eba4f13d2693756d38acf8d3e9aabbd8fdb5     52
# 0xf748879edbe8cca140940788163d7be4d2a2e46a     51
# 0x950d8f1e2e0ec438573a9540ca6f74913df0aeb1     50
# 0xebc391ba182f6d8654a516a44e382cf9c9196831     36
# 0x51018972e0ad6703aa563e43ef11a1bf1ee0ed0e     35
# 0xb518c6e08769cd10eb5d30e5ee2581b87f98dc4c     35
# 0x4647e75bf0c97917be3c994936b7e29b2a3bd375     35
# 0xb384087b00f36f340ab9af0b5f311b629e3035ea     35
# 0xd145f93ea8931d73047eb68b346aa98ab0ced7a8     34
# 0x8b59e1636f1efde992da55d3fa1c621a0a62ba0f     33
# 0xb1ebc277815f6e9900508de585461f8b1550c523     33
# 0xc95932d5a11ecb8eb776ee4ef062888008e9b84d     31
# 0xc6bf41b2273a840a9db867ef4dad463b5635dcd3     30
# 0xbc3847d7e2110b8905bb9e1cbed004df472e4362     28
# Name: delegator, dtype: int64

# %%
delegate_df['indexer'].value_counts()[-60:-40]
# Out:
# 0x17d7dca770ef183355b202435e1ce80a11b53886    60
# 0x60165e465b242d051de4ebadfe0cf55b13f04dc5    59
# 0x9f491ce41ffa24a074176106ed9c59b0ae504427    57
# 0xa3eb195c91c428d48c7ce24301f0dfbaf972b5d7    56
# 0xc9348dcaef652791033a22f79a2024363e23d32b    56
# 0x48eecbc147a4b97e30fd03ef738b9305812e0287    56
# 0xc9899dfdca2b2ef3972ce25e3f1ba0b05cb457b6    56
# 0xe7738d5679b54781a5482baa48dadfde624ed7d5    56
# 0xa92bd8c16ae3266cf3b80ba0152735e9a8460ce7    55
# 0xf251d93b7ef841ff72bee6bb603d1782092e7db1    54
# 0x1b536a13d1a18eb51bb216cf69aa89fcd0b1badc    53
# 0xf4e5f4e0f8ec4d6235bd2fb0443058584ebffbff    53
# 0x7fa7d0212ac64b48efaf62055b9d2d274d14403f    53
# 0xe8832ba6aaf83d80d9e7578415e97576093f4d9f    50
# 0xfd4b9c44ee7afb7f98df3dda40aead6acd9f41f4    49
# 0x011bdfea664ece919d895d174f57331460056236    48
# 0x914cefe3b3e68cdf813c4b947ce2db76c28c2287    47
# 0x71ba24da09cc80d400c1c419ec459c3e130e37e6    45
# 0x1873a56a404b21df3c69c0c105dd65b4e43d88e6    44
# 0x61590afb7e2c612ef8c441356ee82db8cd90a5d6    44
# Name: indexer, dtype: int64

# %%
single_indexer_df = delegate_df[delegate_df['indexer'] == '0xfb5b40098cdfec1564ae5b94d4deed116b887d08'].sort_values('blockNumber')

# %%
single_indexer_df = single_indexer_df.sort_values(['blockNumber', 'logIndex'])
single_indexer_df
# Out:
#                                type  blockNumber  \
# 56890  delegationParametersUpdateds     11520130
# 58130               stakeDepositeds     11520130
# 56891  delegationParametersUpdateds     11520152
# 27444            allocationCreateds     11521514
# 1855                 stakeDelegates     11521751
# 27453            allocationCreateds     11521825
# 1884                 stakeDelegates     11522585
# 37998          allocationCollecteds     11529751
# 38011          allocationCollecteds     11529831
# 2441                 stakeDelegates     11550583
# 58793               stakeDepositeds     11612930
# 47451             allocationCloseds     11612930
# 27964            allocationCreateds     11612931
# 58830               stakeDepositeds     11619568
# 47477             allocationCloseds     11619568
# 28045            allocationCreateds     11627242
# 59111               stakeDepositeds     11665114
# 64074                rebateClaimeds     11665114
# 6365                 stakeDelegates     11778510
# 17213         stakeDelegatedLockeds     11780511
# 6605                 stakeDelegates     11799649
# 60010               stakeDepositeds     11856317
# 48354             allocationCloseds     11856317
# 60011               stakeDepositeds     11856325
# 48355             allocationCloseds     11856325
# 28839            allocationCreateds     11856356
# 17743         stakeDelegatedLockeds     11856654
# 17807         stakeDelegatedLockeds     11865303
# 22920      stakeDelegatedWithdrawns     11968087
# 9563                 stakeDelegates     12021701
# 23255      stakeDelegatedWithdrawns     12039449
# 23579      stakeDelegatedWithdrawns     12072175
# 19578         stakeDelegatedLockeds     12242961
# 61501               stakeDepositeds     12299918
# 49587             allocationCloseds     12299918
# 30076            allocationCreateds     12299919
# 61523               stakeDepositeds     12315284
# 49643             allocationCloseds     12315284
# 25111      stakeDelegatedWithdrawns     12445797
# 20691         stakeDelegatedLockeds     12503583
# 26243      stakeDelegatedWithdrawns     12734214
#
#                                         delegator  \
# 56890                                         NaN
# 58130                                         NaN
# 56891                                         NaN
# 27444                                         NaN
# 1855   0x63f8168f665f79101a0e0da2313cd1391e1c5e27
# 27453                                         NaN
# 1884   0x40f657e85bbb5cc7beb402da315c3fe1974442bf
# 37998                                         NaN
# 38011                                         NaN
# 2441   0x950d8f1e2e0ec438573a9540ca6f74913df0aeb1
# 58793                                         NaN
# 47451                                         NaN
# 27964                                         NaN
# 58830                                         NaN
# 47477                                         NaN
# 28045                                         NaN
# 59111                                         NaN
# 64074                                         NaN
# 6365   0xcbb08e918e828bfd46a0e32e3365e80d7502c7d9
# 17213  0xcbb08e918e828bfd46a0e32e3365e80d7502c7d9
# 6605   0xd45d0eb21cb9dbf86012cbd574fb66d1a2c6d800
# 60010                                         NaN
# 48354                                         NaN
# 60011                                         NaN
# 48355                                         NaN
# 28839                                         NaN
# 17743  0x40f657e85bbb5cc7beb402da315c3fe1974442bf
# 17807  0x63f8168f665f79101a0e0da2313cd1391e1c5e27
# 22920  0xcbb08e918e828bfd46a0e32e3365e80d7502c7d9
# 9563   0x8e0c59ba449ac228016dee5b1bb0990a8be7f8a6
# 23255  0x40f657e85bbb5cc7beb402da315c3fe1974442bf
# 23579  0x63f8168f665f79101a0e0da2313cd1391e1c5e27
# 19578  0x8e0c59ba449ac228016dee5b1bb0990a8be7f8a6
# 61501                                         NaN
# 49587                                         NaN
# 30076                                         NaN
# 61523                                         NaN
# 49643                                         NaN
# 25111  0x8e0c59ba449ac228016dee5b1bb0990a8be7f8a6
# 20691  0x950d8f1e2e0ec438573a9540ca6f74913df0aeb1
# 26243  0x950d8f1e2e0ec438573a9540ca6f74913df0aeb1
#
#                                                       id  \
# 56890  0xb9afb01417c0f363b779446dd59b317ba8aafd8d598d...
# 58130  0xb9afb01417c0f363b779446dd59b317ba8aafd8d598d...
# 56891  0x774b5679cb78818bbb37eb9f45acbae6efdf66743a20...
# 27444  0x88e81aa40bb581fb2adbbca9c29a13315360fbf66431...
# 1855   0x0b035858451535f7ed3388cf2183a73f5f84aaa3245f...
# 27453  0x8328e7cb125953c500b00748535cbb0a00779b0cefaa...
# 1884   0xd42c3095e84a2bb3c577721544923649ffcad9385437...
# 37998  0xa7807ec226a19e05769d98b76bf598a081756026ad9a...
# 38011  0xe48ee30cd73203580b4f9c3e079a9fb9c230ca4a9c51...
# 2441   0xeaeaa9e5cf4850942ec35592147a053d1e92f7a06fc1...
# 58793  0x4d45b9b55fae6f9305c6733aedd208914ad00da18c63...
# 47451  0x4d45b9b55fae6f9305c6733aedd208914ad00da18c63...
# 27964  0x4082a014d84561a9df141904847c68c946a732e904f5...
# 58830  0x8c193b0afb64e8d6151247700474b4eb884bafeedf30...
# 47477  0x8c193b0afb64e8d6151247700474b4eb884bafeedf30...
# 28045  0x7cdb6725bc87912c2a53ba39f314add94da26801f805...
# 59111  0x986488a6d35c389eba4e184712a0535a96139b8b9374...
# 64074  0x986488a6d35c389eba4e184712a0535a96139b8b9374...
# 6365   0x2575195906278d8346a493a4082c9cc4e131d5eacb05...
# 17213  0x85abc6b1bf79d8707caae00dd076550289e14b8ea2cf...
# 6605   0x6f636ff42a39d361836c3d369e5895d7a600b1e2be59...
# 60010  0x771bd4c4b9754823b176a07873f3608dd97bf5982748...
# 48354  0x771bd4c4b9754823b176a07873f3608dd97bf5982748...
# 60011  0x3e9f98ad11aa76d3cd6ed3f922c0ba440a175e7af348...
# 48355  0x3e9f98ad11aa76d3cd6ed3f922c0ba440a175e7af348...
# 28839  0x352efff276f2f97a1f84223289f75610e0b39b46559b...
# 17743  0x875dc1ad16000307ee16e7c84df5109def6e9ffec202...
# 17807  0xd7812422ad53f3439b334ce16a6d9e4226af4d906373...
# 22920  0x8e3a5e02e01ad362290fbfcb8ff267b55f544c46db7a...
# 9563   0xb37b6ef6ed65104bfda5556edec72244f836b7eac0df...
# 23255  0x9194bd7f866d9a2a7da6d19ef58bb3fab3f593fb019c...
# 23579  0x459473e4603b2d1a214a398d2caf7cd4322624c420ad...
# 19578  0x654d57c2c950ca9b627f2789057e347fe8252369d839...
# 61501  0xfacd404c5849d43255f5bf4d0ae80ddad906f5acac85...
# 49587  0xfacd404c5849d43255f5bf4d0ae80ddad906f5acac85...
# 30076  0x0582d63c89f9968d119e643e2dd56fc9e7adbcbe8906...
# 61523  0xb3b43204f81520dea22459885ac6b94e7de880808012...
# 49643  0xb3b43204f81520dea22459885ac6b94e7de880808012...
# 25111  0x178c91eacaf037cb37ef88dab7cd0b5586ce9c7b77fc...
# 20691  0x2d5e953cdae1aed48781ab9fd1fe47d67f203da117ae...
# 26243  0xd14c84492b5d4964e5b4c4b4a79907d25fc5d3cd0708...
#
#                                           indexer  logIndex  \
# 56890  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       157
# 58130  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       158
# 56891  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       229
# 27444  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       107
# 1855   0xfb5b40098cdfec1564ae5b94d4deed116b887d08        30
# 27453  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       384
# 1884   0xfb5b40098cdfec1564ae5b94d4deed116b887d08        89
# 37998  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       296
# 38011  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       264
# 2441   0xfb5b40098cdfec1564ae5b94d4deed116b887d08       327
# 58793  0xfb5b40098cdfec1564ae5b94d4deed116b887d08        38
# 47451  0xfb5b40098cdfec1564ae5b94d4deed116b887d08        39
# 27964  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       190
# 58830  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       229
# 47477  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       230
# 28045  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       192
# 59111  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       215
# 64074  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       216
# 6365   0xfb5b40098cdfec1564ae5b94d4deed116b887d08       285
# 17213  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       210
# 6605   0xfb5b40098cdfec1564ae5b94d4deed116b887d08       140
# 60010  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       233
# 48354  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       234
# 60011  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       103
# 48355  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       104
# 28839  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       319
# 17743  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       133
# 17807  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       171
# 22920  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       129
# 9563   0xfb5b40098cdfec1564ae5b94d4deed116b887d08        41
# 23255  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       118
# 23579  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       123
# 19578  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       168
# 61501  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       199
# 49587  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       200
# 30076  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       237
# 61523  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       286
# 49643  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       287
# 25111  0xfb5b40098cdfec1564ae5b94d4deed116b887d08        13
# 20691  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       204
# 26243  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       288
#
#                         shares                     tokens     eventTime  \
# 56890                      NaN                        NaN           NaN
# 58130                      NaN  1243612000000000000000000           NaN
# 56891                      NaN                        NaN           NaN
# 27444                      NaN   620000000000000000000000           NaN
# 1855    1094500000000000000000     1094500000000000000000           NaN
# 27453                      NaN   620000000000000000000000           NaN
# 1884     995000000000000000000      995000000000000000000           NaN
# 37998                      NaN         350987412670748874           NaN
# 38011                      NaN         619137696904111205           NaN
# 2441   55222500000000000000000    55222500000000000000000           NaN
# 58793                      NaN     6992278838280839213400           NaN
# 47451                      NaN   620000000000000000000000           NaN
# 27964                      NaN   620000000000000000000000           NaN
# 58830                      NaN     7412390565199642429400           NaN
# 47477                      NaN   620000000000000000000000           NaN
# 28045                      NaN   620000000000000000000000           NaN
# 59111                      NaN         314500799690706457           NaN
# 64074                      NaN         314500799690706457           NaN
# 6365    2895065106115432857526     2985000000000000000000           NaN
# 17213   2895065106115432857526     2984999999999999999999  1.612319e+09
# 6605   19300434040769552383512    19900000000000000000000           NaN
# 60010                      NaN     9556847374872508219000           NaN
# 48354                      NaN   620000000000000000000000           NaN
# 60011                      NaN    10360487389770169927000           NaN
# 48355                      NaN   620000000000000000000000           NaN
# 28839                      NaN  1240000000000000000000000           NaN
# 17743    994999999999999990363     1057880681157946400522  1.613330e+09
# 17807   1094499999999999951777     1163668749273741000575  1.613445e+09
# 22920                      NaN     2984999999999999999999           NaN
# 9563    3753469591583507658440     3990676350000000000000           NaN
# 23255                      NaN     1057880681157946400522           NaN
# 23579                      NaN     1163668749273741000575           NaN
# 19578   3753469591583507658440     3990676349999999999999  1.618467e+09
# 61501                      NaN    23772682490475838525600           NaN
# 49587                      NaN  1240000000000000000000000           NaN
# 30076                      NaN  1240000000000000000000000           NaN
# 61523                      NaN      781892419941371744000           NaN
# 49643                      NaN  1240000000000000000000000           NaN
# 25111                      NaN     3990676349999999999999           NaN
# 20691  55222500000000000000000    60961231577108159627625  1.621947e+09
# 26243                      NaN    60961231577108159627625           NaN
#
#        until  ...  epoch                               subgraphDeploymentID  \
# 56890    NaN  ...    NaN                                                NaN
# 58130    NaN  ...    NaN                                                NaN
# 56891    NaN  ...    NaN                                                NaN
# 27444    NaN  ...   11.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 1855     NaN  ...    NaN                                                NaN
# 27453    NaN  ...   11.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 1884     NaN  ...    NaN                                                NaN
# 37998    NaN  ...   12.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 38011    NaN  ...   12.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 2441     NaN  ...    NaN                                                NaN
# 58793    NaN  ...    NaN                                                NaN
# 47451    NaN  ...   25.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 27964    NaN  ...   25.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 58830    NaN  ...    NaN                                                NaN
# 47477    NaN  ...   26.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 28045    NaN  ...   27.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 59111    NaN  ...    NaN                                                NaN
# 64074    NaN  ...   32.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 6365     NaN  ...    NaN                                                NaN
# 17213   78.0  ...    NaN                                                NaN
# 6605     NaN  ...    NaN                                                NaN
# 60010    NaN  ...    NaN                                                NaN
# 48354    NaN  ...   61.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 60011    NaN  ...    NaN                                                NaN
# 48355    NaN  ...   61.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 28839    NaN  ...   61.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 17743   89.0  ...    NaN                                                NaN
# 17807   90.0  ...    NaN                                                NaN
# 22920    NaN  ...    NaN                                                NaN
# 9563     NaN  ...    NaN                                                NaN
# 23255    NaN  ...    NaN                                                NaN
# 23579    NaN  ...    NaN                                                NaN
# 19578  147.0  ...    NaN                                                NaN
# 61501    NaN  ...    NaN                                                NaN
# 49587    NaN  ...  128.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 30076    NaN  ...  128.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 61523    NaN  ...    NaN                                                NaN
# 49643    NaN  ...  130.0  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 25111    NaN  ...    NaN                                                NaN
# 20691  187.0  ...    NaN                                                NaN
# 26243    NaN  ...    NaN                                                NaN
#
#             curationFees                                        from  \
# 56890                NaN                                         NaN
# 58130                NaN                                         NaN
# 56891                NaN                                         NaN
# 27444                NaN                                         NaN
# 1855                 NaN                                         NaN
# 27453                NaN                                         NaN
# 1884                 NaN                                         NaN
# 37998  34747753854404138  0x9fd8ac559219d4dd463193d1fb0433f7844f730f
# 38011  61294631993507009  0x9fd8ac559219d4dd463193d1fb0433f7844f730f
# 2441                 NaN                                         NaN
# 58793                NaN                                         NaN
# 47451                NaN                                         NaN
# 27964                NaN                                         NaN
# 58830                NaN                                         NaN
# 47477                NaN                                         NaN
# 28045                NaN                                         NaN
# 59111                NaN                                         NaN
# 64074                NaN                                         NaN
# 6365                 NaN                                         NaN
# 17213                NaN                                         NaN
# 6605                 NaN                                         NaN
# 60010                NaN                                         NaN
# 48354                NaN                                         NaN
# 60011                NaN                                         NaN
# 48355                NaN                                         NaN
# 28839                NaN                                         NaN
# 17743                NaN                                         NaN
# 17807                NaN                                         NaN
# 22920                NaN                                         NaN
# 9563                 NaN                                         NaN
# 23255                NaN                                         NaN
# 23579                NaN                                         NaN
# 19578                NaN                                         NaN
# 61501                NaN                                         NaN
# 49587                NaN                                         NaN
# 30076                NaN                                         NaN
# 61523                NaN                                         NaN
# 49643                NaN                                         NaN
# 25111                NaN                                         NaN
# 20691                NaN                                         NaN
# 26243                NaN                                         NaN
#
#                rebateFees isDelegator  \
# 56890                 NaN         NaN
# 58130                 NaN         NaN
# 56891                 NaN         NaN
# 27444                 NaN         NaN
# 1855                  NaN         NaN
# 27453                 NaN         NaN
# 1884                  NaN         NaN
# 37998  312729784689637248         NaN
# 38011  551651687941563084         NaN
# 2441                  NaN         NaN
# 58793                 NaN         NaN
# 47451                 NaN       False
# 27964                 NaN         NaN
# 58830                 NaN         NaN
# 47477                 NaN       False
# 28045                 NaN         NaN
# 59111                 NaN         NaN
# 64074                 NaN         NaN
# 6365                  NaN         NaN
# 17213                 NaN         NaN
# 6605                  NaN         NaN
# 60010                 NaN         NaN
# 48354                 NaN       False
# 60011                 NaN         NaN
# 48355                 NaN       False
# 28839                 NaN         NaN
# 17743                 NaN         NaN
# 17807                 NaN         NaN
# 22920                 NaN         NaN
# 9563                  NaN         NaN
# 23255                 NaN         NaN
# 23579                 NaN         NaN
# 19578                 NaN         NaN
# 61501                 NaN         NaN
# 49587                 NaN       False
# 30076                 NaN         NaN
# 61523                 NaN         NaN
# 49643                 NaN       False
# 25111                 NaN         NaN
# 20691                 NaN         NaN
# 26243                 NaN         NaN
#
#                                            sender indexingRewardCut  \
# 56890                                         NaN         1000000.0
# 58130                                         NaN               NaN
# 56891                                         NaN          890000.0
# 27444                                         NaN               NaN
# 1855                                          NaN               NaN
# 27453                                         NaN               NaN
# 1884                                          NaN               NaN
# 37998                                         NaN               NaN
# 38011                                         NaN               NaN
# 2441                                          NaN               NaN
# 58793                                         NaN               NaN
# 47451  0x71ad386f301f38c41df53fcbc182b4b2ac87dd56               NaN
# 27964                                         NaN               NaN
# 58830                                         NaN               NaN
# 47477  0x71ad386f301f38c41df53fcbc182b4b2ac87dd56               NaN
# 28045                                         NaN               NaN
# 59111                                         NaN               NaN
# 64074                                         NaN               NaN
# 6365                                          NaN               NaN
# 17213                                         NaN               NaN
# 6605                                          NaN               NaN
# 60010                                         NaN               NaN
# 48354  0x71ad386f301f38c41df53fcbc182b4b2ac87dd56               NaN
# 60011                                         NaN               NaN
# 48355  0x71ad386f301f38c41df53fcbc182b4b2ac87dd56               NaN
# 28839                                         NaN               NaN
# 17743                                         NaN               NaN
# 17807                                         NaN               NaN
# 22920                                         NaN               NaN
# 9563                                          NaN               NaN
# 23255                                         NaN               NaN
# 23579                                         NaN               NaN
# 19578                                         NaN               NaN
# 61501                                         NaN               NaN
# 49587  0x71ad386f301f38c41df53fcbc182b4b2ac87dd56               NaN
# 30076                                         NaN               NaN
# 61523                                         NaN               NaN
# 49643  0x71ad386f301f38c41df53fcbc182b4b2ac87dd56               NaN
# 25111                                         NaN               NaN
# 20691                                         NaN               NaN
# 26243                                         NaN               NaN
#
#        queryFeeCut     delegationFees
# 56890    1000000.0                NaN
# 58130          NaN                NaN
# 56891     890000.0                NaN
# 27444          NaN                NaN
# 1855           NaN                NaN
# 27453          NaN                NaN
# 1884           NaN                NaN
# 37998          NaN                NaN
# 38011          NaN                NaN
# 2441           NaN                NaN
# 58793          NaN                NaN
# 47451          NaN                NaN
# 27964          NaN                NaN
# 58830          NaN                NaN
# 47477          NaN                NaN
# 28045          NaN                NaN
# 59111          NaN                NaN
# 64074          NaN  38870885355031136
# 6365           NaN                NaN
# 17213          NaN                NaN
# 6605           NaN                NaN
# 60010          NaN                NaN
# 48354          NaN                NaN
# 60011          NaN                NaN
# 48355          NaN                NaN
# 28839          NaN                NaN
# 17743          NaN                NaN
# 17807          NaN                NaN
# 22920          NaN                NaN
# 9563           NaN                NaN
# 23255          NaN                NaN
# 23579          NaN                NaN
# 19578          NaN                NaN
# 61501          NaN                NaN
# 49587          NaN                NaN
# 30076          NaN                NaN
# 61523          NaN                NaN
# 49643          NaN                NaN
# 25111          NaN                NaN
# 20691          NaN                NaN
# 26243          NaN                NaN
#
# [41 rows x 21 columns]

# %%
single_indexer_df[single_indexer_df['type'] == 'rebateClaimeds']
# Out:
#                  type  blockNumber delegator  \
# 64074  rebateClaimeds     11665114       NaN
#
#                                                       id  \
# 64074  0x986488a6d35c389eba4e184712a0535a96139b8b9374...
#
#                                           indexer  logIndex shares  \
# 64074  0xfb5b40098cdfec1564ae5b94d4deed116b887d08       216    NaN
#
#                    tokens  eventTime  until  ... epoch  \
# 64074  314500799690706457        NaN    NaN  ...  32.0
#
#                                     subgraphDeploymentID curationFees from  \
# 64074  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...          NaN  NaN
#
#       rebateFees isDelegator sender indexingRewardCut  queryFeeCut  \
# 64074        NaN         NaN    NaN               NaN          NaN
#
#           delegationFees
# 64074  38870885355031136
#
# [1 rows x 21 columns]

# %%
single_indexer_df_allocation_create = single_indexer_df[single_indexer_df['type'] == 'allocationCreateds']
single_indexer_df_stake_delegate = single_indexer_df[single_indexer_df['type'] == 'stakeDelegates']
single_indexer_df_allocation_collect = single_indexer_df[single_indexer_df['type'] == 'allocationCollecteds']
single_indexer_df_allocation_close = single_indexer_df[single_indexer_df['type'] == 'allocationCloseds']
single_indexer_df_stake_lock = single_indexer_df[single_indexer_df['type'] == 'stakeDelegatedLockeds']
single_indexer_df_stake_withdraw = single_indexer_df[single_indexer_df['type'] == 'stakeDelegatedWithdrawns']
single_indexer_df_rebate_claim = single_indexer_df[single_indexer_df['type'] == 'rebateClaimeds']

# %%
single_indexer_df_allocation_create.to_csv('SIallocationCreateds.csv', index = False, header = True)
single_indexer_df_stake_delegate.to_csv('SIstakeDelegateds.csv', index = False, header = True)
single_indexer_df_allocation_collect.to_csv('SIallocationCollecteds.csv', index = False, header = True)
single_indexer_df_allocation_close.to_csv('SIallocationCloseds.csv', index = False, header = True)
single_indexer_df_stake_lock.to_csv('SIstakeLockeds.csv', index = False, header = True)
single_indexer_df_stake_withdraw.to_csv('SIstakeWithdrawns.csv', index = False, header = True)
single_indexer_df_rebate_claim.to_csv('SIrebateClaimeds.csv', index = False, header = True)

# %%
single_indexer_df.to_csv('singleIndexer.csv', index = False, header = True)

# %%
delegate_df.loc[delegate_df['delegator'].str.contains('0xb16a4cc8a24ce7dfd6e517097717aff6fb10c0e7')].sort_values('blockNumber')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-e8b99b879a25> in <module>
# ----> 1 delegate_df.loc[delegate_df['delegator'].str.contains('0xb16a4cc8a24ce7dfd6e517097717aff6fb10c0e7')].sort_values('blockNumber')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1141             self._validate_key(key, axis)
#    1142             return self._get_slice_axis(key, axis=axis)
# -> 1143         elif com.is_bool_indexer(key):
#    1144             return self._getbool_axis(key, axis=axis)
#    1145         elif is_list_like_indexer(key):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
single_indexer_df.to_csv('singleIndexer.csv', index = False, header = True)
