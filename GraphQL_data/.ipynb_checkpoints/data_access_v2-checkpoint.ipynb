# %% [markdown]
# # TheGraph data access
# We plan to visualize and monitor the flow of delegated stake, total delegation pool and indexer allocation process.
#
# The current data come from [event data subgraph](https://thegraph.com/explorer/subgraph/fordn/graph-network-events?selected=playground)
#
# More research plan see [hackmd](https://hackmd.io/@Jiajia20/BkOoEZODd)
#
#
# ## visualization
# - request GraphQL data API -> JSON -> PANDAS
# - the current subgraph seemd only load the first 200 record (even if I specify first:1000)
# - I'm able to load 200 at a time and combine them with 'first, skip'
#
# ## To do
# - [x] get specitialty subgraph
# - [x] double check pagination problem
# - [x] clean the notebook and upload

# %%
import json
import requests
import pandas as pd

# %% [markdown]
# ## 0 -  Pagination

# %%
import pandas as pd
import json
import requests
import matplotlib.pyplot as plt

# %%
def query_theGraph(raw_query, field_name, url, verbose=False):

    query_parts =raw_query.split(')')
    paginator = ", where: {}"
    #this expectes the raw query to gave a `first:1000` term
    n = 0
    records = []
    while n < 20:
        if (n == 0):
            query = 'query '+query_parts[0] + ')' + query_parts[1]
        else:
            print(f'request {n+1}')
            query = 'query '+query_parts[0]+ ', where: {blockTime_gt: ' + indexer + '})'+query_parts[1]

        if verbose:
            print(query)

        r = requests.post(url, json = {'query':query})

        try:
            d = json.loads(r.content)['data'][field_name]
        except:
            #print(r.content)
            errors = json.loads(r.content)['errors']
            #print(errors)
            for e in errors:
                print(e['message'])

        print(f'results {len(d)}')
        records.extend(d)
        print(f'total {len(records)}')
        indexer = d[-1]['blockTime']
        
        n += 1
        if len(d) < 1000:
            break
        
    return pd.DataFrame(records)

# %%
url = 'https://api.thegraph.com/subgraphs/name/fordn/graph-network-events'

raw_query = '''query{
  allocationCreateds(first: 1000) {
    id
    blockTime
    logIndex
    indexer
    subgraphDeploymentID
    epoch
    tokens
    allocationID
  }  
}
'''
field_name = 'allocationCreateds'

subgraph_tvl2 = query_theGraph(raw_query, field_name, url, True)
# Out:
# query query{
#   allocationCreateds(first: 1000) {
#     id
#     blockTime
#     logIndex
#     indexer
#     subgraphDeploymentID
#     epoch
#     tokens
#     allocationID
#   }
# }
#
# results 1000
# total 1000
# request 2
# query query{
#   allocationCreateds(first: 1000, where: {blockTime_gt: 1621048421}) {
#     id
#     blockTime
#     logIndex
#     indexer
#     subgraphDeploymentID
#     epoch
#     tokens
#     allocationID
#   }
# }
#
# results 1000
# total 2000
# request 3
# query query{
#   allocationCreateds(first: 1000, where: {blockTime_gt: 1623084504}) {
#     id
#     blockTime
#     logIndex
#     indexer
#     subgraphDeploymentID
#     epoch
#     tokens
#     allocationID
#   }
# }
#
# results 243
# total 2243

# %% [markdown]
# ## 1 - Allocation Data of Indexer

# %%
url = 'https://api.thegraph.com/subgraphs/name/fordn/graph-network-events'

raw_query = '''query{
  allocationCreateds(first: 1000) {
    id
    blockTime
    logIndex
    indexer
    subgraphDeploymentID
    epoch
    tokens
    allocationID
  }  
}
'''
field_name = 'allocationCreateds'

df4 = query_theGraph(raw_query, field_name, url, True)
# Out:
# query query{
#   allocationCreateds(first: 1000) {
#     id
#     blockTime
#     logIndex
#     indexer
#     subgraphDeploymentID
#     epoch
#     tokens
#     allocationID
#   }
# }
#
# results 1000
# total 1000
# request 2
# query query{
#   allocationCreateds(first: 1000, where: {blockTime_gt: 1621048421}) {
#     id
#     blockTime
#     logIndex
#     indexer
#     subgraphDeploymentID
#     epoch
#     tokens
#     allocationID
#   }
# }
#
# results 1000
# total 2000
# request 3
# query query{
#   allocationCreateds(first: 1000, where: {blockTime_gt: 1623084504}) {
#     id
#     blockTime
#     logIndex
#     indexer
#     subgraphDeploymentID
#     epoch
#     tokens
#     allocationID
#   }
# }
#
# results 243
# total 2243

# %%
df4
# Out:
#                                     allocationID   blockTime epoch  \
# 0     0xc4caf36f2c05f7877624a220864a5f77f2f2dde1  1621256240   151
# 1     0xb652e85f5d2e2b1ecb7b164a8febe792f2395f01  1619621558   132
# 2     0xf8e196fe61725e3fa8b9718a490e7f009cc6b988  1620152411   138
# 3     0x82d17f1cd44222e8c7a175ee6972eb15c25c3f92  1618832206   123
# 4     0xf3f1ef3d81a4de26b8dbe307719f1967638d8335  1610142497    25
# ...                                          ...         ...   ...
# 2238  0x11b2876029ba4c65370225f794d956faccfe2a6b  1623282231   174
# 2239  0x0bce7e93c739b7f2397519f651918baf84ffc736  1623307743   174
# 2240  0x545aedb56f254bd40894758ba82956423e009177  1623409800   175
# 2241  0x355bad48e2c39707ff1712f9457271c009a76280  1623320307   174
# 2242  0x3059afadfe12737c5972cddf04c79193c201c24f  1623402665   175
#
#                                                      id  \
# 0     0x000c497dc03839292bda44a17d5c59d80bd73c55d66f...
# 1     0x002b7445f820908ebe271470c2a2894dd99b304c5a36...
# 2     0x003985cead0dc0624496b977387d2092399756e8c979...
# 3     0x004ac4e8aab6bd2330d9f118217f3997cb82c71f3d77...
# 4     0x0055b8942d40f8e157aa7e7d4e9fd64451a7175d646c...
# ...                                                 ...
# 2238  0xf73d7f28c2ddb8457cc9120964ca9250f464f4fdf168...
# 2239  0xf9399587ae13ff981bb0cef29b2b6fd08ffe89d54472...
# 2240  0xf94fd719e05abffc63e3dd8be7d9d381928fad40aa23...
# 2241  0xfa754010779b13b1a58e3b5ff916f51bf68f489354a4...
# 2242  0xfde8155a24b20bccec65a1862a14513855083cab2e72...
#
#                                          indexer logIndex  \
# 0     0x4b1c684dc4ad3c77cbaae5f16051c269b79116d2      281
# 1     0xa543abe0ea61b4bbbca3f402442bda4bf7d45992      208
# 2     0xea214c6bae7032ea09bbf970aa30612bfc896a3b      170
# 3     0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e      276
# 4     0x4d6a8776a164776c93618233a0003e8894e7e6c2      136
# ...                                          ...      ...
# 2238  0x9238584c74e5fa445a8f72a4d4ef4699dd783852      153
# 2239  0xd9c7cdf09d868467d9f94f885dd68e850e278118      217
# 2240  0x60165e465b242d051de4ebadfe0cf55b13f04dc5      237
# 2241  0xbe9d7c691792937ca7e2535652886ff390cc5b86      238
# 2242  0x643c5f5223ba68e06766b194b274c4d90dd42dc8      206
#
#                                    subgraphDeploymentID  \
# 0     0x014e8a3184d5fad198123419a7b54d5f7c9f8a981116...
# 1     0x4a008334f8e7ea21be223d15462084f51abcc0e6625f...
# 2     0xc420d79a888eb0e34203bfeca1048d35f9763b9880a9...
# 3     0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 4     0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# ...                                                 ...
# 2238  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 2239  0xc064c354bc21dd958b1d41b67b8ef161b75d2246b425...
# 2240  0xa7d9d3a173d3d62ce3d05c2d29f3447b04edc248cbcf...
# 2241  0x014e8a3184d5fad198123419a7b54d5f7c9f8a981116...
# 2242  0xc420d79a888eb0e34203bfeca1048d35f9763b9880a9...
#
#                           tokens
# 0         5000000000000000000000
# 1       390000000000000000000000
# 2        17360700000000000000000
# 3     39024000000000000000000000
# 4     15164869000000000000000000
# ...                          ...
# 2238   4428631000000000000000000
# 2239    100000000000000000000000
# 2240   7440000000000000000000000
# 2241   2999210000000000000000000
# 2242  34070738000000000000000000
#
# [2243 rows x 8 columns]

# %%
url = 'https://api.thegraph.com/subgraphs/name/fordn/graph-network-events'

query = """query{
  allocationCreateds(first: 1000) {
    id
    blockTime
    logIndex
    indexer
    subgraphDeploymentID
    epoch
    tokens
    allocationID
  }  
}"""
r = requests.post(url, json = {'query':query})
p = json.loads(r.content)

#create pandas df
json_data = json.loads(r.text)
df_data = json_data['data']['allocationCreateds']
df4 = pd.DataFrame(df_data)

df4.insert(0, 'type', 'allocationCreateds')
df4 = df4.sort_values(by=['blockTime'],ascending=True)
#df4.to_csv('stakeDelegateds.csv', index = False, header=True)

# %%
url = 'https://api.thegraph.com/subgraphs/name/fordn/graph-network-events'

query = """query{
  allocationCollecteds(first: 1000) {
    id
    blockTime
    logIndex
    indexer
    subgraphDeploymentID
    epoch
    tokens
    allocationID
    from
    curationFees
    rebateFees
  }
  
}"""
r = requests.post(url, json = {'query':query})
p = json.loads(r.content)

#create pandas df
json_data = json.loads(r.text)
df_data = json_data['data']['allocationCollecteds']
df5 = pd.DataFrame(df_data)

df5.insert(0, 'type', 'allocationCollecteds')
df5 = df5.sort_values(by=['blockTime'],ascending=True)
#df4.to_csv('stakeDelegateds.csv', index = False, header=True)

# %% [markdown]
# ## 2 - delegated stake

# %% [markdown]
# ### Delegated Stakes in df

# %%
#thanks to @Markus for the code and @Ford for the new subgraph


url = 'https://api.thegraph.com/subgraphs/name/fordn/graph-network-events'

query = """query{
  stakeDelegateds (first:1000) {
    id
    blockTime
    logIndex
    indexer
    delegator
    tokens
    shares
  }
}"""
r = requests.post(url, json = {'query':query})
p = json.loads(r.content)

#create pandas df
json_data = json.loads(r.text)
df_data = json_data['data']['stakeDelegateds']
df = pd.DataFrame(df_data)

# %%
df.insert(0, 'type', 'stakeDelegates')

# %%
df = df.sort_values(by=['blockTime'],ascending=True)
df.to_csv('stakeDelegateds.csv', index = False, header=True)

# %% [markdown]
# ### Locked Stake in df2

# %%
url = 'https://api.thegraph.com/subgraphs/name/fordn/graph-network-events'

query = """query{
  stakeDelegatedLockeds(first:1000) {
    id
    blockTime
    logIndex
    eventTime
    indexer
    delegator
    tokens
    shares
    until
  }
 }"""
r = requests.post(url, json = {'query':query})
p = json.loads(r.content)

#create pandas df
import pandas as pd
json_data = json.loads(r.text)
df_data = json_data['data']['stakeDelegatedLockeds']
df2 = pd.DataFrame(df_data)

# %%
df2.insert(0,'type','stakeDelegatedLockeds')

# %%
df2 = df2.sort_values(by=['blockTime'],ascending=True)
df2.to_csv('stakeDelegatedLockeds.csv', index = False, header=True)

# %% [markdown]
# ### WithDraw in df3

# %%
url = 'https://api.thegraph.com/subgraphs/name/fordn/graph-network-events'

query = """query{stakeDelegatedWithdrawns (first:1000) {
    id
    blockTime
    logIndex
    indexer
    delegator
    tokens
}
}"""
r = requests.post(url, json = {'query':query})
p = json.loads(r.content)

#create pandas df
import pandas as pd
json_data = json.loads(r.text)
df_data = json_data['data']['stakeDelegatedWithdrawns']
df3 = pd.DataFrame(df_data)

# %%
df3.insert(0,'type','stakeDelegatedWithdrawns')

# %%
df3 = df3.sort_values(by=['blockTime'],ascending=True)
df3.to_csv('stakeDelegatedWithdrawns.csv', index = False, header=True)

# %% [markdown]
# ### Merge and vis
# Adding column
# - [merging with concat](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
# - [insert columns](https://stackoverflow.com/questions/29517072/add-column-to-dataframe-with-constant-value)
#
# deal with duplicate
# - [insert index](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html)
# - [result row index](https://stackoverflow.com/questions/19609631/python-changing-row-index-of-pandas-data-frame)
# - [drop duplicate](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html)
#
# visualization
# - [plot with multiple line](https://stackoverflow.com/questions/29233283/plotting-multiple-lines-in-different-colors-with-pandas-dataframe)
# - [pandas native](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html)
#
# type cast
# - [casting string](https://datatofish.com/string-to-integer-dataframe/)
# - use `float` for bigger numbers

# %%
# frames = [df, df2, df3]
frames = [df, df2, df3,df4,df5]
result = pd.concat(frames)
result
# Out:
#                      type   blockTime  \
# 409        stakeDelegates  1608262679
# 832        stakeDelegates  1608263358
# 924        stakeDelegates  1608269302
# 596        stakeDelegates  1608294293
# 684        stakeDelegates  1608295011
# ..                    ...         ...
# 857  allocationCollecteds  1623269216
# 582  allocationCollecteds  1623281515
# 514  allocationCollecteds  1623282923
# 389  allocationCollecteds  1623308398
# 367  allocationCollecteds  1623438322
#
#                                       delegator  \
# 409  0xb7797cb7b4a031c4c1e04ea14824fa5d8d30beed
# 832  0x6c615cb1e310d0909698ef4992958d849bf4a45c
# 924  0x7eb692f22af33d637aab31f9277653235682ebe6
# 596  0x795f50722cf5ad82f78dda8dc8f7b235332977c3
# 684  0x4e58b97ce2c9a687ff6df2ba7f8f7217ad44327d
# ..                                          ...
# 857                                         NaN
# 582                                         NaN
# 514                                         NaN
# 389                                         NaN
# 367                                         NaN
#
#                                                     id  \
# 409  0x07f058e4212ea4115857cd68ed38d6eba0a8fc84977c...
# 832  0x106191a769d4ba4690aeb8f366a1ffb00f500c03ecc6...
# 924  0x11d12e4e40232247ba695bb303b0ea709873707de2cb...
# 596  0x0b6977f0cc00e06d12e273a8d66cc99f318096d2d1d3...
# 684  0x0d9dca553ffa90476e1e0af918fda92b4986699e608e...
# ..                                                 ...
# 857  0x1a402433316c75429545066accf3e49cb959461521c8...
# 582  0x1253c4b353a3596901da8661aeccbef6f6664234fb5e...
# 514  0x101e4dcd79470563b43d06a6daa8f0b1b0761e766c5f...
# 389  0x0c3765f48cf0e08072a601c094ba830419712a99b308...
# 367  0x0b059f5d76f3525b2f87b7c017599d5b8f8d7b312cd4...
#
#                                         indexer logIndex  \
# 409  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e       65
# 832  0x4fedde33607cfda2c82a999accb427d1170987d9       95
# 924  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e       48
# 596  0x9238584c74e5fa445a8f72a4d4ef4699dd783852      233
# 684  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e       94
# ..                                          ...      ...
# 857  0x62a0bd1d110ff4e5b793119e95fc07c9d1fc8c4a      238
# 582  0x62a0bd1d110ff4e5b793119e95fc07c9d1fc8c4a       72
# 514  0x9238584c74e5fa445a8f72a4d4ef4699dd783852      299
# 389  0xbe9d7c691792937ca7e2535652886ff390cc5b86      143
# 367  0xd11e05240a50e2eedb03e72d4c9c6465bc05f2a4      170
#
#                       shares                   tokens eventTime until  \
# 409  39800000000000000000000  39800000000000000000000       NaN   NaN
# 832  33167330000000000000000  33167330000000000000000       NaN   NaN
# 924   4002893379514657642500   4002893379514657642500       NaN   NaN
# 596  37810000000000000000000  37810000000000000000000       NaN   NaN
# 684  96816288431287805084285  96816288431287805084285       NaN   NaN
# ..                       ...                      ...       ...   ...
# 857                      NaN    263300262839474183815       NaN   NaN
# 582                      NaN      3009622569664822781       NaN   NaN
# 514                      NaN    501534515614179178669       NaN   NaN
# 389                      NaN    467365600000000000000       NaN   NaN
# 367                      NaN     49311872147707762003       NaN   NaN
#
#                                    allocationID epoch  \
# 409                                         NaN   NaN
# 832                                         NaN   NaN
# 924                                         NaN   NaN
# 596                                         NaN   NaN
# 684                                         NaN   NaN
# ..                                          ...   ...
# 857  0xda0e00eb641223464719781d95dd1ad407198c4c   173
# 582  0xb67d6aba791b79cffdacea30bd05c911b8576295   174
# 514  0xff01167622a71b6927f101e91ed3d5dfce276117   174
# 389  0x3244f370f21f9f22aed2c103057668e4addc4f9b   174
# 367  0x61b4834f285bf970a3c61a115c3df05fac914a92   175
#
#                                   subgraphDeploymentID          curationFees  \
# 409                                                NaN                   NaN
# 832                                                NaN                   NaN
# 924                                                NaN                   NaN
# 596                                                NaN                   NaN
# 684                                                NaN                   NaN
# ..                                                 ...                   ...
# 857  0x5e48ee6773576d45a38934cb19780b5c8c75f8c36e65...  26066726021107944197
# 582  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...    297952634396817455
# 514  0x4a008334f8e7ea21be223d15462084f51abcc0e6625f...  49651917045803738688
# 389  0xc420d79a888eb0e34203bfeca1048d35f9763b9880a9...                     0
# 367  0xbbde25a2c85f55b53b7698b9476610c3d1202d88870e...   4881875342623068438
#
#                                            from             rebateFees
# 409                                         NaN                    NaN
# 832                                         NaN                    NaN
# 924                                         NaN                    NaN
# 596                                         NaN                    NaN
# 684                                         NaN                    NaN
# ..                                          ...                    ...
# 857  0x4a53cf3b3eda545dc61dee0ca21ea8996c94385f  234600534189971497780
# 582  0x4a53cf3b3eda545dc61dee0ca21ea8996c94385f    2681573709571357099
# 514  0x4a53cf3b3eda545dc61dee0ca21ea8996c94385f  446867253412233648195
# 389  0x4a53cf3b3eda545dc61dee0ca21ea8996c94385f  462691944000000000000
# 367  0x4a53cf3b3eda545dc61dee0ca21ea8996c94385f   43936878083607615945
#
# [5000 rows x 16 columns]

# %%
result.to_csv('merged.csv', index = False, header=True)

# %%
type(df.blockTime[0])
# Out:
# str

# %%
type(2288500000000000000000)
# Out:
# int

# %%
import numpy as np
result['blockTime'] = result['blockTime'].astype(int)
result['tokens'] = result['tokens'].astype(float)
#result['tokens'] = pd.to_numeric(result['tokens'])
result = result.sort_values('blockTime')

# %%
import matplotlib.pyplot as plt

#result_p  = result.drop_duplicates(subset=['blockTime'])
result.set_index(['blockTime', 'delegator', 'indexer'], append=True)
result
result.insert(0,'index_2',0)
result.index_2 = range(5000)

# %%
result
# Out:
#      index_2                      type   blockTime  \
# 776        0        allocationCreateds  1608253393
# 796        1        allocationCreateds  1608260076
# 456        2     stakeDelegatedLockeds  1608260777
# 401        3            stakeDelegates  1608262679
# 820        4            stakeDelegates  1608263358
# ..       ...                       ...         ...
# 353     4995        allocationCreateds  1623189388
# 535     4996        allocationCreateds  1623189952
# 244     4997        allocationCreateds  1623190264
# 828     4998  stakeDelegatedWithdrawns  1623190829
# 336     4999        allocationCreateds  1623191272
#
#                                       delegator  \
# 776                                         NaN
# 796                                         NaN
# 456  0x57b4a5f470c85d4281f7baf5162b59243a3491df
# 401  0xb7797cb7b4a031c4c1e04ea14824fa5d8d30beed
# 820  0x6c615cb1e310d0909698ef4992958d849bf4a45c
# ..                                          ...
# 353                                         NaN
# 535                                         NaN
# 244                                         NaN
# 828  0x279d42cfcefbc6397e8117e4e9245ddb3a8b2f4e
# 336                                         NaN
#
#                                                     id  \
# 776  0x1fd0fa14121d920bde44890feece6cbb592f064e8ed8...
# 796  0x2076c2600fc4986ee6abc0226930b8147cd5c968ed90...
# 456  0x18cb0cf3c94ed5aee7c925b9691535fb78e0419d54e3...
# 401  0x07f058e4212ea4115857cd68ed38d6eba0a8fc84977c...
# 820  0x106191a769d4ba4690aeb8f366a1ffb00f500c03ecc6...
# ..                                                 ...
# 353  0x0db77d7737792dba6db74007969eb318b29214ce603f...
# 535  0x15fda9165bfa030c8e85ed2e0be19d755c39a19582c4...
# 244  0x0a41c7ce6245fd60a85691cefd849c025581ede52453...
# 828  0x3f3e62a004828429d1b8646af29291ab0faa8f20ee49...
# 336  0x0d2b87905374634496732aff5b7710204dacb68d2b42...
#
#                                         indexer logIndex  \
# 776  0xa959b5afe73c6faa803541b5c4edc0492dfda294      297
# 796  0xf3f182e859f789af8d6c2223d15c691471c79a2b      199
# 456  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e       67
# 401  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e       65
# 820  0x4fedde33607cfda2c82a999accb427d1170987d9       95
# ..                                          ...      ...
# 353  0xc60d0c8c74b5d3a33ed51c007ebae682490de261       97
# 535  0x6125ea331851367716bee301ecde7f38a7e429e7      288
# 244  0x6125ea331851367716bee301ecde7f38a7e429e7      164
# 828  0xbb784d9b398271b7a64f975bebde869409691915      290
# 336  0x62a0bd1d110ff4e5b793119e95fc07c9d1fc8c4a      254
#
#                       shares        tokens   eventTime until  \
# 776                      NaN  8.000000e+21         NaN   NaN
# 796                      NaN  2.500000e+22         NaN   NaN
# 456  65257075000000000000000  6.525707e+22  1608260777    32
# 401  39800000000000000000000  3.980000e+22         NaN   NaN
# 820  33167330000000000000000  3.316733e+22         NaN   NaN
# ..                       ...           ...         ...   ...
# 353                      NaN  2.258360e+25         NaN   NaN
# 535                      NaN  2.541490e+25         NaN   NaN
# 244                      NaN  2.541490e+25         NaN   NaN
# 828                      NaN  7.945412e+22         NaN   NaN
# 336                      NaN  1.000000e+24         NaN   NaN
#
#                                    allocationID epoch  \
# 776  0x566bb471e1dec5d97985981b86503dd4be561479     4
# 796  0xa5b928782cef4908a4cbb27f55921e383f984124     4
# 456                                         NaN   NaN
# 401                                         NaN   NaN
# 820                                         NaN   NaN
# ..                                          ...   ...
# 353  0x7d60e52f127d4767c671079674f90064b9116085   172
# 535  0x070a986aef9e692871261c71f7ac570b35b0e8a9   172
# 244  0x78279a215156af74b8359831e57d357653b6730e   172
# 828                                         NaN   NaN
# 336  0x4dc399a980b52156f440ba620be25d29250e49cd   173
#
#                                   subgraphDeploymentID curationFees from  \
# 776  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...          NaN  NaN
# 796  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...          NaN  NaN
# 456                                                NaN          NaN  NaN
# 401                                                NaN          NaN  NaN
# 820                                                NaN          NaN  NaN
# ..                                                 ...          ...  ...
# 353  0xbbde25a2c85f55b53b7698b9476610c3d1202d88870e...          NaN  NaN
# 535  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...          NaN  NaN
# 244  0xbbde25a2c85f55b53b7698b9476610c3d1202d88870e...          NaN  NaN
# 828                                                NaN          NaN  NaN
# 336  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...          NaN  NaN
#
#     rebateFees
# 776        NaN
# 796        NaN
# 456        NaN
# 401        NaN
# 820        NaN
# ..         ...
# 353        NaN
# 535        NaN
# 244        NaN
# 828        NaN
# 336        NaN
#
# [5000 rows x 17 columns]

# %%
result = result.pivot( columns='type', values='tokens')


#result.plot(logy=True)

# %% [markdown]
# ## 3 - Graph Visualization

# %%
import networkx as nx
def pd_to_graph(df):
    G = nx.from_pandas_edgelist(df,
                            source='delegator',
                            target='indexer',
                            edge_key='id',
                            create_using=nx.MultiDiGraph(),
                            edge_attr=True)
    
    unique_indexer = df.indexer.unique()
    for i in unique_indexer:
        G.nodes[i]['type'] = 'indexer'

    unique_delegator = df.delegator.unique()   
    for i in unique_delegator:
        G.nodes[i]['type'] = 'delegator'
    return(G)

# %%
G = pd_to_graph(df)
G

# %%
nx.degree(G)
# Out:
# DiMultiDegreeView({'0xb7797cb7b4a031c4c1e04ea14824fa5d8d30beed': 1, '0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e': 40, '0x6c615cb1e310d0909698ef4992958d849bf4a45c': 1, '0x4fedde33607cfda2c82a999accb427d1170987d9': 8, '0x7eb692f22af33d637aab31f9277653235682ebe6': 1, '0x795f50722cf5ad82f78dda8dc8f7b235332977c3': 1, '0x9238584c74e5fa445a8f72a4d4ef4699dd783852': 81, '0x4e58b97ce2c9a687ff6df2ba7f8f7217ad44327d': 1, '0xe0ddee528856195af906eb5c7645ddcb6dbbe1c0': 1, '0xbf15754dc61f5e552a5c5a51e6b571d567798650': 1, '0x5356df73b293bd9c6e8efd22c99833391ef8821a': 1, '0x620c8a1dc6fbe29c10f9c599c5e29e450bb0ef58': 1, '0x3727321b9b1318c2716b743e4eea28e0c8fc7f58': 1, '0x11b1785d9ac81480c03210e89f1508c8c115888e': 1, '0xddc39dceb6d8fb94d8a9b59cf3bf9a1e7ae19034': 4, '0xcd46cd81694848ab908ffd7a4d713a3baa0b758d': 2, '0x72acbecf3013d7b27421185d3bf369520bf552c8': 3, '0x128b1dec802ddf81681e3d6f113bd83dd
026f48d8a78226ef52': 1, '0xe58c90d9a9da8f20755216100a39b6c646cb26e2': 1, '0x671bc7a0ffa02b0ee90ee03bcd11915df011503a': 21, '0x7bdca7dacc2fb394b76a07e2f4f502892f7032af': 1, '0x26873dbb476f96b7e92869360c4f0c3bc420149e': 1, '0x3a58538b353994bb4703f0458a99224067fd6004': 1, '0xbe9d7c691792937ca7e2535652886ff390cc5b86': 34, '0x6980fd6c85a98df8180123951e46d673b456699c': 2, '0x6c63208e0cf89c7e5cb15a3e5997e15b4fc6f14c': 1, '0x5a8904be09625965d9aec4bffd30d853438a053e': 306, '0x87e7a461828270e4105b77017fd35e92fbb888ed': 1, '0x2a87c1345024ab463acc26417124c433b3069fdd': 1, '0x5d7ab46fb3e00fb3baf7a91a6235c7b41a888581': 1, '0x0dd063ecef2a6fa4e3c25cca22331db11ea47f7e': 1, '0x3f2eeb69778671883c912581cff39d93880b9064': 1, '0xbecfbd38ad4e13968007ea56678504e738bda8a9': 1, '0x09 ...

# %% [markdown]
# ## 4 - Explore
# 1. block number and block time are interchangable measurement of time, but a more crose measure of action timestep. Namely if two transaction happpens in the same block, it will be represented with the same block number and block time, and the actual order of how they happen as unknown in the Graph's framework (futher detail might be searchable in projets like Ether Scan)
#
# 2. event time is NOT unique either
#
# 3.

# %% [markdown]
# ### 4.1 Block number

# %%
df
# Out:
#                type   blockTime                                   delegator  \
# 401  stakeDelegates  1608262679  0xb7797cb7b4a031c4c1e04ea14824fa5d8d30beed
# 820  stakeDelegates  1608263358  0x6c615cb1e310d0909698ef4992958d849bf4a45c
# 912  stakeDelegates  1608269302  0x7eb692f22af33d637aab31f9277653235682ebe6
# 586  stakeDelegates  1608294293  0x795f50722cf5ad82f78dda8dc8f7b235332977c3
# 674  stakeDelegates  1608295011  0x4e58b97ce2c9a687ff6df2ba7f8f7217ad44327d
# ..              ...         ...                                         ...
# 118  stakeDelegates  1623069670  0x6bbcd33742daaf5a4cada3d95dc946f12156c7fe
# 784  stakeDelegates  1623100493  0x465cec40949115603e61933301ef2b574e40e665
# 925  stakeDelegates  1623140004  0x45d09cf3bef4accd9843e18c9c5180804672ce79
# 28   stakeDelegates  1623165277  0x276fbd11b769792e04caf3aab269e852b6ae6221
# 967  stakeDelegates  1623184237  0x3622522a5eb9bba3417ec3d2a437f9d3c5caacee
#
#                                                     id  \
# 401  0x07f058e4212ea4115857cd68ed38d6eba0a8fc84977c...
# 820  0x106191a769d4ba4690aeb8f366a1ffb00f500c03ecc6...
# 912  0x11d12e4e40232247ba695bb303b0ea709873707de2cb...
# 586  0x0b6977f0cc00e06d12e273a8d66cc99f318096d2d1d3...
# 674  0x0d9dca553ffa90476e1e0af918fda92b4986699e608e...
# ..                                                 ...
# 118  0x0242e0b64dea3fa20fadd966570959f1c01b2c2e2dce...
# 784  0x0fc7645040e3f86d43f5bb1c6d360d1a7efc59628075...
# 925  0x120cf83fe6a37e2e4e1249c1157e3026c247a3821704...
# 28   0x006e78f604d4a25759a5330c9f287197ebeab61a1b1b...
# 967  0x12d49d64dee2553f775a8c0328d86c6bb4db2ea78119...
#
#                                         indexer logIndex  \
# 401  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e       65
# 820  0x4fedde33607cfda2c82a999accb427d1170987d9       95
# 912  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e       48
# 586  0x9238584c74e5fa445a8f72a4d4ef4699dd783852      233
# 674  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e       94
# ..                                          ...      ...
# 118  0xbb784d9b398271b7a64f975bebde869409691915      170
# 784  0x5a8904be09625965d9aec4bffd30d853438a053e      281
# 925  0x8b7663dd451c951f39e541188d9f7d9419e94421      395
# 28   0x5a8904be09625965d9aec4bffd30d853438a053e      308
# 967  0xbbf36ec9311d60513c09f952d7530c2ff37e86b4      233
#
#                        shares                     tokens
# 401   39800000000000000000000    39800000000000000000000
# 820   33167330000000000000000    33167330000000000000000
# 912    4002893379514657642500     4002893379514657642500
# 586   37810000000000000000000    37810000000000000000000
# 674   96816288431287805084285    96816288431287805084285
# ..                        ...                        ...
# 118     436019322115679055845     1008450151180600000000
# 784     704505821017269675060      751477572998950000000
# 925  261187500000000000000000   261187500000000000000000
# 28     7526312164328809115665     8030858420596450264390
# 967  979047089813715745310832  1063644055000000000000000
#
# [1000 rows x 8 columns]

# %%
df.sort_values('blockTime')

#examine duplicate
df.loc[[203, 812,949]]
df[df.blockTime == '11520282']
df[df.blockTime == '11727669']
df[df.blockTime == '11727669']

#small number of indexer, and relatively large number of delegators
df.delegator.nunique()
df.id.nunique()

#block numbers are string, to plot and order need to be cast into integers
type(df.blockTime[0])
df['blockTime'] = pd.to_numeric(df.blockTime)
df.blockTime.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4.2 unique delegator and indexer

# %%
df2["inde_del"] = df2["indexer"] + df2["delegator"]
df2['inde_del'].nunique()
df2[df2.inde_del.duplicated()]
# Out:
#                       type   blockTime  \
# 8    stakeDelegatedLockeds  1613170470
# 223  stakeDelegatedLockeds  1613212495
# 128  stakeDelegatedLockeds  1614961433
# 752  stakeDelegatedLockeds  1617347952
# 539  stakeDelegatedLockeds  1617526015
# 761  stakeDelegatedLockeds  1617998341
# 630  stakeDelegatedLockeds  1620377552
# 90   stakeDelegatedLockeds  1620932006
# 866  stakeDelegatedLockeds  1621291785
# 484  stakeDelegatedLockeds  1621349464
# 831  stakeDelegatedLockeds  1621420062
# 507  stakeDelegatedLockeds  1621543962
# 489  stakeDelegatedLockeds  1621544552
# 770  stakeDelegatedLockeds  1621544571
# 273  stakeDelegatedLockeds  1621589781
# 130  stakeDelegatedLockeds  1621596529
# 912  stakeDelegatedLockeds  1621606430
# 726  stakeDelegatedLockeds  1621640382
# 808  stakeDelegatedLockeds  1622144760
# 445  stakeDelegatedLockeds  1622431142
#
#                                       delegator   eventTime  \
# 8    0xbdfbf2a55de91fee5d0eb829fdfd337430862bff  1613170470
# 223  0x5ce95cf658909bf9ebf03dc6e5f32fa0961b689e  1613212495
# 128  0x445ea1ccb8c2c984647484ca9bf0d08adafced60  1614961433
# 752  0x38148ecc2078da7f65e6233dda28efaf4c51e96f  1617347952
# 539  0xf3d2bae54313a3991b086d93576d953d0bae7241  1617526015
# 761  0x445ea1ccb8c2c984647484ca9bf0d08adafced60  1617998341
# 630  0x9ce3aebe5e73cdd5357aa4561fe1b01d78f89fbc  1620377552
ebae682490de261","logIndex":"124","tokens":"1523183332042590527502"},{"blockTime":"1617555369","delegator":"0x993d8b5eb5f4396ce9f62f0ba126ade3c30b8f09","id":"0x01426234f6857bfcbd967f3730cfe25afc6534fa42d79adb3b49dfc162344881-250","indexer":"0x4fedde33607cfda2c82a999accb427d1170987d9","logIndex":"250","tokens":"6069809896395680599085"},{"blockTime":"1613276280","delegator":"0xebc391ba182f6d8654a516a44e382cf9c9196831","id":"0x0153ca944efe42d9774bdf10720fff254ccfbfe7f5002771a178c35021c12d28-207","indexer":"0x48b5687f0595e2a4d581dc72305fbae214345d07","logIndex":"207","tokens":"4739754437556449692757"},{"blockTime":"1619614783","delegator":"0xb919488d2c59b5130fe56e66d41c5bc4d7a2ca51","id":"0x0187b0cba0901dd4d7fb1eb5dc127245cddf7343ea9bf192dd7c2347094d4800-280","indexer":"0xac104dba73822c575713e1ecb06da67af01c54b3","logIndex":"280","tokens":"13971331190291546007094"},{"blockTime":"1623056388","delegator":"0x186706603efa83f26e44fb6f83bb0ef8c165a79f","id":"0x01943f1e7d3c097b5072ea1557e1b95313d2d9ecee3c3c383677ddea5cd86d99-325","indexer":"0x85fe868adf7f5950b052469075556fb207 ...

# %%
len(df)
# Out:
# 1000

# %% [markdown]
# ## This is what we want it to look like

# %%
subgraph_tvl2.head()
# Out:
#                                  allocationID   blockTime epoch  \
# 0  0xc4caf36f2c05f7877624a220864a5f77f2f2dde1  1621256240   151
# 1  0xb652e85f5d2e2b1ecb7b164a8febe792f2395f01  1619621558   132
# 2  0xf8e196fe61725e3fa8b9718a490e7f009cc6b988  1620152411   138
# 3  0x82d17f1cd44222e8c7a175ee6972eb15c25c3f92  1618832206   123
# 4  0xf3f1ef3d81a4de26b8dbe307719f1967638d8335  1610142497    25
#
#                                                   id  \
# 0  0x000c497dc03839292bda44a17d5c59d80bd73c55d66f...
# 1  0x002b7445f820908ebe271470c2a2894dd99b304c5a36...
# 2  0x003985cead0dc0624496b977387d2092399756e8c979...
# 3  0x004ac4e8aab6bd2330d9f118217f3997cb82c71f3d77...
# 4  0x0055b8942d40f8e157aa7e7d4e9fd64451a7175d646c...
#
#                                       indexer logIndex  \
# 0  0x4b1c684dc4ad3c77cbaae5f16051c269b79116d2      281
# 1  0xa543abe0ea61b4bbbca3f402442bda4bf7d45992      208
# 2  0xea214c6bae7032ea09bbf970aa30612bfc896a3b      170
# 3  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e      276
# 4  0x4d6a8776a164776c93618233a0003e8894e7e6c2      136
#
#                                 subgraphDeploymentID  \
# 0  0x014e8a3184d5fad198123419a7b54d5f7c9f8a981116...
# 1  0x4a008334f8e7ea21be223d15462084f51abcc0e6625f...
# 2  0xc420d79a888eb0e34203bfeca1048d35f9763b9880a9...
# 3  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 4  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
#
#                        tokens
# 0      5000000000000000000000
# 1    390000000000000000000000
# 2     17360700000000000000000
# 3  39024000000000000000000000
# 4  15164869000000000000000000

# %% [markdown]
# Dealing with pagination here is a pain and the `query` string above does not actually run in the explorer as written. In order to make it easier to move back and forth between the [explorer](https://thegraph.com/explorer/subgraph/balancer-labs/balancer) and the python environment we should build a function to run the same query we use in the explorer, for example:
# ```
# {pools(first:1000){
#         id
#         liquidity
#     }
# }
# ```

# %%
def query_theGraph(raw_query, field_name, url, verbose=False, hardcap=5000):

    query_parts =raw_query.split(')')
    paginator = ", skip:{}"
    #this expectes the raw query to gave a `first:1000` term
    n = 0
    records = []
    while True:
        print(f'request {n+1}')
        skipper = paginator.format(n*1000)
        query = 'query '+query_parts[0]+skipper+')'+query_parts[1]

        if verbose:
            print(query)

        r = requests.post(url, json = {'query':query})

        try:
            d = json.loads(r.content)['data'][field_name]
        except:
            #print(r.content)
            errors = json.loads(r.content)['errors']
            #print(errors)
            for e in errors:
                print(e['message'])

        print(f'results {len(d)}')
        records.extend(d)
        print(f'total {len(records)}')
        
        if n*1000>hardcap:
            break
        
        n += 1
        if len(d) < 1000:
            break
        
    return pd.DataFrame(records)

# %%
raw_query = '''{pools(first:1000){
        id
        liquidity
    }
}

'''
field_name = 'pools'

subgraph_tvl2 = query_theGraph(raw_query, field_name, url, True)
# Out:
# request 1
# query {pools(first:1000, skip:0){
#         id
#         liquidity
#     }
# }
#
#
# Type `Query` has no field `pools`
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-37-15784abea81b> in <module>
#       8 field_name = 'pools'
#       9
# ---> 10 subgraph_tvl2 = query_theGraph(raw_query, field_name, url, True)
#
# <ipython-input-36-be5ba7d633b3> in query_theGraph(raw_query, field_name, url, verbose, hardcap)
#      25                 print(e['message'])
#      26
# ---> 27         print(f'results {len(d)}')
#      28         records.extend(d)
#      29         print(f'total {len(records)}')
#
# UnboundLocalError: local variable 'd' referenced before assignment

# %%
subgraph_tvl2
# Out:
#                                     allocationID   blockTime epoch  \
# 0     0xc4caf36f2c05f7877624a220864a5f77f2f2dde1  1621256240   151
# 1     0xb652e85f5d2e2b1ecb7b164a8febe792f2395f01  1619621558   132
# 2     0xf8e196fe61725e3fa8b9718a490e7f009cc6b988  1620152411   138
# 3     0x82d17f1cd44222e8c7a175ee6972eb15c25c3f92  1618832206   123
# 4     0xf3f1ef3d81a4de26b8dbe307719f1967638d8335  1610142497    25
# ...                                          ...         ...   ...
# 5783  0xbf4d3ad3b4b3ce9d0d30ac058f29fa24ffff69fe  1621104011   149
# 5784  0x78d14055f95a198996a358593a6abd13fba2a797  1619078955   126
# 5785  0xf8ce8a040b8133f8fcb7260148762061e1a1f5b6  1622743392   167
# 5786  0x124f7cfe0c24af8a03a120c21034c83fe6c0b6ff  1622217461   162
# 5787  0x4ed9c4783bffc285cf238379f26a800aad08e01e  1608816342    10
#
#                                                      id  \
# 0     0x000c497dc03839292bda44a17d5c59d80bd73c55d66f...
# 1     0x002b7445f820908ebe271470c2a2894dd99b304c5a36...
# 2     0x003985cead0dc0624496b977387d2092399756e8c979...
# 3     0x004ac4e8aab6bd2330d9f118217f3997cb82c71f3d77...
# 4     0x0055b8942d40f8e157aa7e7d4e9fd64451a7175d646c...
# ...                                                 ...
# 5783  0xffe594261c9d2a2791038b3da1a7611585a39c6fd931...
# 5784  0xffe67340aa357eb536487046f4d44890c6bba14eeb51...
# 5785  0xfff0f5eea0b539f674b9003f1e4dda16e6d0aa504638...
# 5786  0xfff2225b990d1e9d7319cc826808e44864bfe34ba7d9...
# 5787  0xfff707e506811211cbc673bb953f1dd5cda21be152b8...
#
#                                          indexer logIndex  \
# 0     0x4b1c684dc4ad3c77cbaae5f16051c269b79116d2      281
# 1     0xa543abe0ea61b4bbbca3f402442bda4bf7d45992      208
# 2     0xea214c6bae7032ea09bbf970aa30612bfc896a3b      170
# 3     0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e      276
# 4     0x4d6a8776a164776c93618233a0003e8894e7e6c2      136
# ...                                          ...      ...
# 5783  0xe6368e677871b288294536c8fe6cb1bbeb19f7a2      202
# 5784  0xd93456bf656436e66a8e0a8835c43a6f59afbb37      153
# 5785  0xd9c7cdf09d868467d9f94f885dd68e850e278118      277
# 5786  0x6ac85b9d834b51b14a7b0ed849bb5199e04c05c5       58
# 5787  0xf4e5f4e0f8ec4d6235bd2fb0443058584ebffbff      131
#
#                                    subgraphDeploymentID  \
# 0     0x014e8a3184d5fad198123419a7b54d5f7c9f8a981116...
# 1     0x4a008334f8e7ea21be223d15462084f51abcc0e6625f...
# 2     0xc420d79a888eb0e34203bfeca1048d35f9763b9880a9...
# 3     0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 4     0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# ...                                                 ...
# 5783  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 5784  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 5785  0x014e8a3184d5fad198123419a7b54d5f7c9f8a981116...
# 5786  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 5787  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
#
#                           tokens
# 0         5000000000000000000000
# 1       390000000000000000000000
# 2        17360700000000000000000
# 3     39024000000000000000000000
# 4     15164869000000000000000000
# ...                          ...
# 5783   8000000000000000000000000
# 5784   1365374000000000000000000
# 5785       800000000000000000000
# 5786   1144270000000000000000000
# 5787    464000000000000000000000
#
# [5788 rows x 8 columns]

# %%
subgraph_tvl2.head()
# Out:
#                                  allocationID   blockTime epoch  \
# 0  0xc4caf36f2c05f7877624a220864a5f77f2f2dde1  1621256240   151
# 1  0xb652e85f5d2e2b1ecb7b164a8febe792f2395f01  1619621558   132
# 2  0xf8e196fe61725e3fa8b9718a490e7f009cc6b988  1620152411   138
# 3  0x82d17f1cd44222e8c7a175ee6972eb15c25c3f92  1618832206   123
# 4  0xf3f1ef3d81a4de26b8dbe307719f1967638d8335  1610142497    25
#
#                                                   id  \
# 0  0x000c497dc03839292bda44a17d5c59d80bd73c55d66f...
# 1  0x002b7445f820908ebe271470c2a2894dd99b304c5a36...
# 2  0x003985cead0dc0624496b977387d2092399756e8c979...
# 3  0x004ac4e8aab6bd2330d9f118217f3997cb82c71f3d77...
# 4  0x0055b8942d40f8e157aa7e7d4e9fd64451a7175d646c...
#
#                                       indexer logIndex  \
# 0  0x4b1c684dc4ad3c77cbaae5f16051c269b79116d2      281
# 1  0xa543abe0ea61b4bbbca3f402442bda4bf7d45992      208
# 2  0xea214c6bae7032ea09bbf970aa30612bfc896a3b      170
# 3  0x7ab4cf25330ed7277ac7ab59380b68eea68abb0e      276
# 4  0x4d6a8776a164776c93618233a0003e8894e7e6c2      136
#
#                                 subgraphDeploymentID  \
# 0  0x014e8a3184d5fad198123419a7b54d5f7c9f8a981116...
# 1  0x4a008334f8e7ea21be223d15462084f51abcc0e6625f...
# 2  0xc420d79a888eb0e34203bfeca1048d35f9763b9880a9...
# 3  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
# 4  0x31edcacc9a53bc8ab4be2eeb0d873409da4c4228cb2d...
#
#                        tokens
# 0      5000000000000000000000
# 1    390000000000000000000000
# 2     17360700000000000000000
# 3  39024000000000000000000000
# 4  15164869000000000000000000

# %%
subgraph_tvl2.columns = ['id','liquidity2']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-c67c0962c92a> in <module>
# ----> 1 subgraph_tvl2.columns = ['id','liquidity2']
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5473         try:
#    5474             object.__getattribute__(self, name)
# -> 5475             return object.__setattr__(self, name, value)
#    5476         except AttributeError:
#    5477             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     667     def _set_axis(self, axis: int, labels: Index) -> None:
#     668         labels = ensure_index(labels)
# --> 669         self._mgr.set_axis(axis, labels)
#     670         self._clear_item_cache()
#     671
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 2 elements

# %%
checker = subgraph_tvl.merge(subgraph_tvl2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-54d573cbb8ac> in <module>
# ----> 1 checker = subgraph_tvl.merge(subgraph_tvl2)
#
# NameError: name 'subgraph_tvl' is not defined

# %%
checker['matches'] = checker.liquidity==checker.liquidity2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-fb67c3eaa4cd> in <module>
# ----> 1 checker['matches'] = checker.liquidity==checker.liquidity2
#
# NameError: name 'checker' is not defined

# %%
checker.matches.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-4cbd2916d4b9> in <module>
# ----> 1 checker.matches.describe()
#
# NameError: name 'checker' is not defined

# %% [markdown]
# Now that have checked the data we can proceed with some exploratory analysis.

# %%
subgraph_tvl.liquidity= subgraph_tvl.liquidity.apply(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-5f64e072a143> in <module>
# ----> 1 subgraph_tvl.liquidity= subgraph_tvl.liquidity.apply(float)
#
# NameError: name 'subgraph_tvl' is not defined

# %%
subgraph_tvl.sort_values('liquidity', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-53d3ced2eca6> in <module>
# ----> 1 subgraph_tvl.sort_values('liquidity', inplace=True)
#
# NameError: name 'subgraph_tvl' is not defined

# %%
subgraph_tvl.liquidity
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-69c62abfac5f> in <module>
# ----> 1 subgraph_tvl.liquidity
#
# NameError: name 'subgraph_tvl' is not defined

# %%
plt_df=subgraph_tvl[subgraph_tvl.liquidity>1].copy().sort_values('liquidity', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b7497537b072> in <module>
# ----> 1 plt_df=subgraph_tvl[subgraph_tvl.liquidity>1].copy().sort_values('liquidity', ascending=False)
#
# NameError: name 'subgraph_tvl' is not defined

# %%
subgraph_tvl.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-930e5810cacd> in <module>
# ----> 1 subgraph_tvl.describe()
#
# NameError: name 'subgraph_tvl' is not defined

# %%
plt_df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-99b9d2ee2ca9> in <module>
# ----> 1 plt_df.tail()
#
# NameError: name 'plt_df' is not defined

# %%
plt_df.plot(x='id', y='liquidity', logy=True)
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-626b479e4154> in <module>
# ----> 1 plt_df.plot(x='id', y='liquidity', logy=True)
#       2 plt.xticks(rotation=90)
#
# NameError: name 'plt_df' is not defined

# %%
plt_df['cumulative liquidity'] = plt_df.liquidity.cumsum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-78b5bdb4b9c7> in <module>
# ----> 1 plt_df['cumulative liquidity'] = plt_df.liquidity.cumsum()
#
# NameError: name 'plt_df' is not defined

# %%
plt_df.plot(x='id', y='cumulative liquidity', logy=False)
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-8dcfcc4874b3> in <module>
# ----> 1 plt_df.plot(x='id', y='cumulative liquidity', logy=False)
#       2 plt.xticks(rotation=90)
#
# NameError: name 'plt_df' is not defined
